# %%
import satellite_access_functions as saf
import satellite_modeling_functions as smf
import datetime as dt
import numpy as np
import skyfield.api as skyfld
import pandas as pd

# %%
# boundaries for coordinates
east_bound = -150 # - 150
west_bound = -165 # - 165
north_bound = 30 # 30 
south_bound = 15 # 15

# time range for sat data
start_time = dt.datetime(2023, 1, 1)
#end_time = dt.datetime(2023, 6, 1)
end_time = dt.datetime(2023, 2, 1) # smaller one just for testing before beefing this up

# names of satellites which will be queried. Total of 65 SAR/EO sats in this dataset
sats_to_query = ['SKYSAT', 'PNEO', 'PLEIADES 1', 'SPOT', 'NOVASAR', 'CAPELLA', 'ICEYE']

# %%
# generate the coordinate ranges
lons = np.arange(start=west_bound, stop=east_bound)
lats = np.arange(start=south_bound, stop=north_bound)

# generate tuples w/ format (GEO, lat, lon)
coordinates = [(f'{str(lat).rjust(2,"0").strip("-")}N{str(lon).rjust(3,"0").strip("-")}E', lat, lon) for lat in lats for lon in lons]

# generate time series data -> slice off last item because its equal to the end_time
time_data = saf.generate_sat_time_series(start_time, end_time, interval='1T')[:-1] # T for minutes

# load the skyfield timescale data
ts = skyfld.load.timescale()

# load the sat data for each satellite
tle_file = 'ephemeral_data/ephemeral_data_2022_01_01_2023_12_31.csv'
# load it as a dataframe with only the object name (satellite name, epoch, and TLE lines)
ephemeral_data = pd.read_csv(tle_file, parse_dates=['EPOCH'])[['OBJECT_NAME', 'EPOCH', 'TLE_LINE1', 'TLE_LINE2']]
# all the data gets loaded, then subset to the EPOCH data between the start and end time of the quered range 
ephemeral_data = ephemeral_data[(ephemeral_data['EPOCH'] >= start_time) & (ephemeral_data['EPOCH'] < end_time)]

# create a dictionary with a key for each satellite and a value of the dataframe of ephemeral data corresponding to this satellite
ephemeral_dict = {sat: ephemeral_data[ephemeral_data.OBJECT_NAME==sat] for sat in ephemeral_data.OBJECT_NAME.unique()}

# vectorize the is_earth_point_visible function 
# I just create a massive numpy array of objects and abuse vectorization to compute things faster
vectorized_sat_in_view = np.vectorize(saf.is_earth_point_visible)

#static time array -> gets passed around a lot for the skyfield functions
static_time_arr = np.array([t.utc_datetime() for t in time_data], dtype='<M8[ns]')
# Out:
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1546141024.py:29: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   static_time_arr = np.array([t.utc_datetime() for t in time_data], dtype='<M8[ns]')

# %%
# adds a satellite object for each value in the ephemeral dict based off of the TLE for the corresponding row
for key in ephemeral_dict.keys():
	ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
	
	ephemeral_dict[key] = ephemeral_dict[key][['OBJECT_NAME', 'Satellite_Object', 'EPOCH']]
# Out:
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)
# /var/folders/h1/j78pvvdx6s36x0qw2pwymct40000gn/T/ipykernel_20606/1172061913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ephemeral_dict[key]['Satellite_Object'] = ephemeral_dict[key].apply(lambda row: skyfld.EarthSatellite(row['TLE_LINE1'], row['TLE_LINE2'], row.OBJECT_NAME, skyfld.load.timescale()),axis=1)

# %%
# Now we expand out the df's in the dicts to include all time series. 
# this whole function gets real ugly real quick and is a whore for RAM so be warned... I'm sorry
for key in ephemeral_dict.keys():
	ephemeral_dict[key] = smf.map_and_reindex_ephemeral_data(ephemeral_dict[key], str(start_time).split(' ')[0], str(end_time).split(' ')[0])
	# need to remove values that are greater than the end time. This happens sometimes if the map and reindex pulls data from the future
	ephemeral_dict[key] = ephemeral_dict[key][ephemeral_dict[key].Time < end_time].drop_duplicates(subset = ['Time'], keep='first')

# %%
for geo, lat, lon in coordinates:
	# initialize the earth point
	earth_point = skyfld.Topos(latitude_degrees=lat, longitude_degrees=lon)
	# create a big array of these earth points to allow vectorization of sat_in_view functionality... im sorry lil laptop
	big_point_array = np.full((len(time_data),), earth_point, dtype=object)

	# init data frame which will be written to CSV
	geo_accesses = pd.DataFrame()

	# name for csv that will be written
	file_name = f'access_{geo}_{start_time.isoformat().split("T")[0]}_{end_time.isoformat().split("T")[0]}.csv'
	path = 'access_data_hawaii_v2/'

	# iterate through each of the 65 satellites
    # we'll start with a single satellite and work up from there: 
	for sat in ephemeral_dict.keys():
		# fields to export:
		sat_name = ephemeral_dict[sat]['OBJECT_NAME'][0]
		#sat_id = sat.OBJECT_ID

		# computational section:
		# grossly memory inefficient, but much faster -> needed to vectorize
		big_sat_array = ephemeral_dict[sat]['Satellite_Object']

		# apply the vectorized operation
		satellite_accesses = vectorized_sat_in_view(big_sat_array, big_point_array, np.array(time_data))
		v_df = pd.DataFrame({'Access': satellite_accesses, 'Time': static_time_arr})
		start_indices = np.where((v_df.Access * 1).diff() > 0)
		end_indices = np.where((v_df.Access * 1).diff() < 0)
		access_starts = v_df.iloc[start_indices]['Time'].values
		access_ends = v_df.iloc[end_indices]['Time'].values
		access_df = pd.DataFrame()
		# edge case for when window goes into the next day
		if len(access_starts) > len(access_ends):
			access_ends = np.append(access_ends, static_time_arr[-1])
		elif len(access_ends) > len(access_starts):
			access_starts = np.append(static_time_arr[-0], access_starts)
		access_df = pd.DataFrame({'ACCESS_START': access_starts, 'ACCESS_END': access_ends})
		#access_df['ACCESS_START'] = access_starts
		#access_df['ACCESS_END'] = access_ends
		access_df['DURATION'] = access_df['ACCESS_END'] - access_df['ACCESS_START']
		access_df['DURATION_SECONDS'] = access_df['DURATION'].dt.total_seconds()
		access_df['SAT_NAME'] = sat_name
		#access_df['SAT_ID'] = sat_id
		geo_accesses = pd.concat([geo_accesses, access_df])
		print(f'Completed {sat} for {geo}')

	geo_accesses['LAT'] = lat
	geo_accesses['LON'] = lon
	geo_accesses['GEO'] = geo
	geo_access = geo_accesses[['GEO', 'SAT_NAME', 'ACCESS_START', 'ACCESS_END', 'DURATION', 'DURATION_SECONDS', 'LAT', 'LON']]
	geo_access.to_csv(path + file_name, index=False)
	print(f'Completed GEO: {geo.strip("-")}\n')
# Out:
# Completed CAPELLA-1 for 15N165E
# Completed CAPELLA-2 for 15N165E
# Completed CAPELLA-3 (WHITNEY) for 15N165E
# Completed CAPELLA-4 (WHITNEY) for 15N165E
# Completed CAPELLA-5 (WHITNEY) for 15N165E
# Completed CAPELLA-6 (WHITNEY) for 15N165E
# Completed CAPELLA-7 (WHITNEY) for 15N165E
# Completed CAPELLA-8 (WHITNEY) for 15N165E
# Completed ICEYE-X1 for 15N165E
# Completed ICEYE-X11 for 15N165E
# Completed ICEYE-X12 for 15N165E
# Completed ICEYE-X13 for 15N165E
# Completed ICEYE-X14 for 15N165E
# Completed ICEYE-X15 for 15N165E
# Completed ICEYE-X16 for 15N165E
# Completed ICEYE-X17 for 15N165E
# Completed ICEYE-X18 for 15N165E
# Completed ICEYE-X19 for 15N165E
# Completed ICEYE-X2 for 15N165E
# Completed ICEYE-X20 for 15N165E
# Completed ICEYE-X21 for 15N165E
# Completed ICEYE-X24 for 15N165E
# Completed ICEYE-X27 for 15N165E
# Completed ICEYE-X4 for 15N165E
# Completed ICEYE-X5 for 15N165E
# Completed ICEYE-X6 for 15N165E
# Completed ICEYE-X7 for 15N165E
# Completed ICEYE-X8 for 15N165E
# Completed ICEYE-X9 for 15N165E
# Completed NOVASAR 1 for 15N165E
# Completed PLEIADES 1 for 15N165E
# Completed PLEIADES 1B for 15N165E
# Completed PNEO3 for 15N165E
# Completed PNEO4 for 15N165E
# Completed SKYSAT 1 for 15N165E
# Completed SKYSAT 2 for 15N165E
# Completed SKYSAT C1 for 15N165E
# Completed SKYSAT C10 for 15N165E
# Completed SKYSAT C11 for 15N165E
# Completed SKYSAT C12 for 15N165E
# Completed SKYSAT C13 for 15N165E
# Completed SKYSAT C14 for 15N165E
# Completed SKYSAT C15 for 15N165E
# Completed SKYSAT C16 for 15N165E
# Completed SKYSAT C17 for 15N165E
# Completed SKYSAT C18 for 15N165E
# Completed SKYSAT C19 for 15N165E
# Completed SKYSAT C2 for 15N165E
# Completed SKYSAT C3 for 15N165E
# Completed SKYSAT C4 for 15N165E
# Completed SKYSAT C5 for 15N165E
# Completed SKYSAT C6 for 15N165E
# Completed SKYSAT C7 for 15N165E
# Completed SKYSAT C8 for 15N165E
# Completed SKYSAT C9 for 15N165E
# Completed SPOT 1 for 15N165E
# Completed SPOT 2 for 15N165E
# Completed SPOT 3 for 15N165E
# Completed SPOT 4 for 15N165E
# Completed SPOT 4 DEB for 15N165E
# Completed SPOT 5 for 15N165E
# Completed SPOT 6 for 15N165E
# Completed SPOT 7 for 15N165E
# Completed GEO: 15N165E
# Completed CAPELLA-1 for 15N164E
# Completed CAPELLA-2 for 15N164E
# Completed CAPELLA-3 (WHITNEY) for 15N164E
# Completed CAPELLA-4 (WHITNEY) for 15N164E
# Completed CAPELLA-5 (WHITNEY) for 15N164E
# Completed CAPELLA-6 (WHITNEY) for 15N164E
# Completed CAPELLA-7 (WHITNEY) for 15N164E
# Completed CAPELLA-8 (WHITNEY) for 15N164E
# Completed ICEYE-X1 for 15N164E
# Completed ICEYE-X11 for 15N164E
# Completed ICEYE-X12 for 15N164E
# Completed ICEYE-X13 for 15N164E
# Completed ICEYE-X14 for 15N164E
# Completed ICEYE-X15 for 15N164E
# Completed ICEYE-X16 for 15N164E
# Completed ICEYE-X17 for 15N164E
# Completed ICEYE-X18 for 15N164E
# Completed ICEYE-X19 for 15N164E
# Completed ICEYE-X2 for 15N164E
# Completed ICEYE-X20 for 15N164E
# Completed ICEYE-X21 for 15N164E
# Completed ICEYE-X24 for 15N164E
# Completed ICEYE-X27 for 15N164E
# Completed ICEYE-X4 for 15N164E
# Completed ICEYE-X5 for 15N164E
# Completed ICEYE-X6 for 15N164E
# Completed ICEYE-X7 for 15N164E
# Completed ICEYE-X8 for 15N164E
# Completed ICEYE-X9 for 15N164E
# Completed NOVASAR 1 for 15N164E
# Completed PLEIADES 1 for 15N164E
# Completed PLEIADES 1B for 15N164E
# Completed PNEO3 for 15N164E
# Completed PNEO4 for 15N164E
# Completed SKYSAT 1 for 15N164E
# Completed SKYSAT 2 for 15N164E
# Completed SKYSAT C1 for 15N164E
# Completed SKYSAT C10 for 15N164E
# Completed SKYSAT C11 for 15N164E
# Completed SKYSAT C12 for 15N164E
# Completed SKYSAT C13 for 15N164E
# Completed SKYSAT C14 for 15N164E
# Completed SKYSAT C15 for 15N164E
# Completed SKYSAT C16 for 15N164E
# Completed SKYSAT C17 for 15N164E
# Completed SKYSAT C18 for 15N164E
# Completed SKYSAT C19 for 15N164E
# Completed SKYSAT C2 for 15N164E
# Completed SKYSAT C3 for 15N164E
# Completed SKYSAT C4 for 15N164E
# Completed SKYSAT C5 for 15N164E
# Completed SKYSAT C6 for 15N164E
# Completed SKYSAT C7 for 15N164E
# Completed SKYSAT C8 for 15N164E
# Completed SKYSAT C9 for 15N164E
# Completed SPOT 1 for 15N164E
# Completed SPOT 2 for 15N164E
# Completed SPOT 3 for 15N164E
# Completed SPOT 4 for 15N164E
# Completed SPOT 4 DEB for 15N164E
# Completed SPOT 5 for 15N164E
# Completed SPOT 6 for 15N164E
# Completed SPOT 7 for 15N164E
# Completed GEO: 15N164E
# Completed CAPELLA-1 for 15N163E
# Completed CAPELLA-2 for 15N163E
# Completed CAPELLA-3 (WHITNEY) for 15N163E
# Completed CAPELLA-4 (WHITNEY) for 15N163E
# Completed CAPELLA-5 (WHITNEY) for 15N163E
# Completed CAPELLA-6 (WHITNEY) for 15N163E
# Completed CAPELLA-7 (WHITNEY) for 15N163E
# Completed CAPELLA-8 (WHITNEY) for 15N163E
# Completed ICEYE-X1 for 15N163E
# Completed ICEYE-X11 for 15N163E
# Completed ICEYE-X12 for 15N163E
# Completed ICEYE-X13 for 15N163E
# Completed ICEYE-X14 for 15N163E
# Completed ICEYE-X15 for 15N163E
# Completed ICEYE-X16 for 15N163E
# Completed ICEYE-X17 for 15N163E
# Completed ICEYE-X18 for 15N163E
# Completed ICEYE-X19 for 15N163E
# Completed ICEYE-X2 for 15N163E
# Completed ICEYE-X20 for 15N163E
# Completed ICEYE-X21 for 15N163E
# Completed ICEYE-X24 for 15N163E
# Completed ICEYE-X27 for 15N163E
# Completed ICEYE-X4 for 15N163E
# Completed ICEYE-X5 for 15N163E
# Completed ICEYE-X6 for 15N163E
# Completed ICEYE-X7 for 15N163E
# Completed ICEYE-X8 for 15N163E
# Completed ICEYE-X9 for 15N163E
# Completed NOVASAR 1 for 15N163E
# Completed PLEIADES 1 for 15N163E
# Completed PLEIADES 1B for 15N163E
# Completed PNEO3 for 15N163E
# Completed PNEO4 for 15N163E
# Completed SKYSAT 1 for 15N163E
# Completed SKYSAT 2 for 15N163E
# Completed SKYSAT C1 for 15N163E
# Completed SKYSAT C10 for 15N163E
# Completed SKYSAT C11 for 15N163E
# Completed SKYSAT C12 for 15N163E
# Completed SKYSAT C13 for 15N163E
# Completed SKYSAT C14 for 15N163E
# Completed SKYSAT C15 for 15N163E
# Completed SKYSAT C16 for 15N163E
# Completed SKYSAT C17 for 15N163E
# Completed SKYSAT C18 for 15N163E
# Completed SKYSAT C19 for 15N163E
# Completed SKYSAT C2 for 15N163E
# Completed SKYSAT C3 for 15N163E
# Completed SKYSAT C4 for 15N163E
# Completed SKYSAT C5 for 15N163E
# Completed SKYSAT C6 for 15N163E
# Completed SKYSAT C7 for 15N163E
# Completed SKYSAT C8 for 15N163E
# Completed SKYSAT C9 for 15N163E
# Completed SPOT 1 for 15N163E
# Completed SPOT 2 for 15N163E
# Completed SPOT 3 for 15N163E
# Completed SPOT 4 for 15N163E
# Completed SPOT 4 DEB for 15N163E
# Completed SPOT 5 for 15N163E
# Completed SPOT 6 for 15N163E
# Completed SPOT 7 for 15N163E
# Completed GEO: 15N163E
# Completed CAPELLA-1 for 15N162E
# Completed CAPELLA-2 for 15N162E
# Completed CAPELLA-3 (WHITNEY) for 15N162E
# Completed CAPELLA-4 (WHITNEY) for 15N162E
# Completed CAPELLA-5 (WHITNEY) for 15N162E
# Completed CAPELLA-6 (WHITNEY) for 15N162E
# Completed CAPELLA-7 (WHITNEY) for 15N162E
# Completed CAPELLA-8 (WHITNEY) for 15N162E
# Completed ICEYE-X1 for 15N162E
# Completed ICEYE-X11 for 15N162E
# Completed ICEYE-X12 for 15N162E
# Completed ICEYE-X13 for 15N162E
# Completed ICEYE-X14 for 15N162E
# Completed ICEYE-X15 for 15N162E
# Completed ICEYE-X16 for 15N162E
# Completed ICEYE-X17 for 15N162E
# Completed ICEYE-X18 for 15N162E
# Completed ICEYE-X19 for 15N162E
# Completed ICEYE-X2 for 15N162E
# Completed ICEYE-X20 for 15N162E
# Completed ICEYE-X21 for 15N162E
# Completed ICEYE-X24 for 15N162E
# Completed ICEYE-X27 for 15N162E
# Completed ICEYE-X4 for 15N162E
# Completed ICEYE-X5 for 15N162E
# Completed ICEYE-X6 for 15N162E
# Completed ICEYE-X7 for 15N162E
# Completed ICEYE-X8 for 15N162E
# Completed ICEYE-X9 for 15N162E
# Completed NOVASAR 1 for 15N162E
# Completed PLEIADES 1 for 15N162E
# Completed PLEIADES 1B for 15N162E
# Completed PNEO3 for 15N162E
# Completed PNEO4 for 15N162E
# Completed SKYSAT 1 for 15N162E
# Completed SKYSAT 2 for 15N162E
# Completed SKYSAT C1 for 15N162E
# Completed SKYSAT C10 for 15N162E
# Completed SKYSAT C11 for 15N162E
# Completed SKYSAT C12 for 15N162E
# Completed SKYSAT C13 for 15N162E
# Completed SKYSAT C14 for 15N162E
# Completed SKYSAT C15 for 15N162E
# Completed SKYSAT C16 for 15N162E
# Completed SKYSAT C17 for 15N162E
# Completed SKYSAT C18 for 15N162E
# Completed SKYSAT C19 for 15N162E
# Completed SKYSAT C2 for 15N162E
# Completed SKYSAT C3 for 15N162E
# Completed SKYSAT C4 for 15N162E
# Completed SKYSAT C5 for 15N162E
# Completed SKYSAT C6 for 15N162E
# Completed SKYSAT C7 for 15N162E
# Completed SKYSAT C8 for 15N162E
# Completed SKYSAT C9 for 15N162E
# Completed SPOT 1 for 15N162E
# Completed SPOT 2 for 15N162E
# Completed SPOT 3 for 15N162E
# Completed SPOT 4 for 15N162E
# Completed SPOT 4 DEB for 15N162E
# Completed SPOT 5 for 15N162E
# Completed SPOT 6 for 15N162E
# Completed SPOT 7 for 15N162E
# Completed GEO: 15N162E
# Completed CAPELLA-1 for 15N161E
# Completed CAPELLA-2 for 15N161E
# Completed CAPELLA-3 (WHITNEY) for 15N161E
# Completed CAPELLA-4 (WHITNEY) for 15N161E
# Completed CAPELLA-5 (WHITNEY) for 15N161E
# Completed CAPELLA-6 (WHITNEY) for 15N161E
# Completed CAPELLA-7 (WHITNEY) for 15N161E
# Completed CAPELLA-8 (WHITNEY) for 15N161E
# Completed ICEYE-X1 for 15N161E
# Completed ICEYE-X11 for 15N161E
# Completed ICEYE-X12 for 15N161E
# Completed ICEYE-X13 for 15N161E
# Completed ICEYE-X14 for 15N161E
# Completed ICEYE-X15 for 15N161E
# Completed ICEYE-X16 for 15N161E
# Completed ICEYE-X17 for 15N161E
# Completed ICEYE-X18 for 15N161E
# Completed ICEYE-X19 for 15N161E
# Completed ICEYE-X2 for 15N161E
# Completed ICEYE-X20 for 15N161E
# Completed ICEYE-X21 for 15N161E
# Completed ICEYE-X24 for 15N161E
# Completed ICEYE-X27 for 15N161E
# Completed ICEYE-X4 for 15N161E
# Completed ICEYE-X5 for 15N161E
# Completed ICEYE-X6 for 15N161E
# Completed ICEYE-X7 for 15N161E
# Completed ICEYE-X8 for 15N161E
# Completed ICEYE-X9 for 15N161E
# Completed NOVASAR 1 for 15N161E
# Completed PLEIADES 1 for 15N161E
# Completed PLEIADES 1B for 15N161E
# Completed PNEO3 for 15N161E
# Completed PNEO4 for 15N161E
# Completed SKYSAT 1 for 15N161E
# Completed SKYSAT 2 for 15N161E
# Completed SKYSAT C1 for 15N161E
# Completed SKYSAT C10 for 15N161E
# Completed SKYSAT C11 for 15N161E
# Completed SKYSAT C12 for 15N161E
# Completed SKYSAT C13 for 15N161E
# Completed SKYSAT C14 for 15N161E
# Completed SKYSAT C15 for 15N161E
# Completed SKYSAT C16 for 15N161E
# Completed SKYSAT C17 for 15N161E
# Completed SKYSAT C18 for 15N161E
# Completed SKYSAT C19 for 15N161E
# Completed SKYSAT C2 for 15N161E
# Completed SKYSAT C3 for 15N161E
# Completed SKYSAT C4 for 15N161E
# Completed SKYSAT C5 for 15N161E
# Completed SKYSAT C6 for 15N161E
# Completed SKYSAT C7 for 15N161E
# Completed SKYSAT C8 for 15N161E
# Completed SKYSAT C9 for 15N161E
# Completed SPOT 1 for 15N161E
# Completed SPOT 2 for 15N161E
# Completed SPOT 3 for 15N161E
# Completed SPOT 4 for 15N161E
# Completed SPOT 4 DEB for 15N161E
# Completed SPOT 5 for 15N161E
# Completed SPOT 6 for 15N161E
# Completed SPOT 7 for 15N161E
# Completed GEO: 15N161E
# Completed CAPELLA-1 for 15N160E
# Completed CAPELLA-2 for 15N160E
# Completed CAPELLA-3 (WHITNEY) for 15N160E
# Completed CAPELLA-4 (WHITNEY) for 15N160E
# Completed CAPELLA-5 (WHITNEY) for 15N160E
# Completed CAPELLA-6 (WHITNEY) for 15N160E
# Completed CAPELLA-7 (WHITNEY) for 15N160E
# Completed CAPELLA-8 (WHITNEY) for 15N160E
# Completed ICEYE-X1 for 15N160E
# Completed ICEYE-X11 for 15N160E
# Completed ICEYE-X12 for 15N160E
# Completed ICEYE-X13 for 15N160E
# Completed ICEYE-X14 for 15N160E
# Completed ICEYE-X15 for 15N160E
# Completed ICEYE-X16 for 15N160E
# Completed ICEYE-X17 for 15N160E
# Completed ICEYE-X18 for 15N160E
# Completed ICEYE-X19 for 15N160E
# Completed ICEYE-X2 for 15N160E
# Completed ICEYE-X20 for 15N160E
# Completed ICEYE-X21 for 15N160E
# Completed ICEYE-X24 for 15N160E
# Completed ICEYE-X27 for 15N160E
# Completed ICEYE-X4 for 15N160E
# Completed ICEYE-X5 for 15N160E
# Completed ICEYE-X6 for 15N160E
# Completed ICEYE-X7 for 15N160E
# Completed ICEYE-X8 for 15N160E
# Completed ICEYE-X9 for 15N160E
# Completed NOVASAR 1 for 15N160E
# Completed PLEIADES 1 for 15N160E
# Completed PLEIADES 1B for 15N160E
# Completed PNEO3 for 15N160E
# Completed PNEO4 for 15N160E
# Completed SKYSAT 1 for 15N160E
# Completed SKYSAT 2 for 15N160E
# Completed SKYSAT C1 for 15N160E
# Completed SKYSAT C10 for 15N160E
# Completed SKYSAT C11 for 15N160E
# Completed SKYSAT C12 for 15N160E
# Completed SKYSAT C13 for 15N160E
# Completed SKYSAT C14 for 15N160E
# Completed SKYSAT C15 for 15N160E
# Completed SKYSAT C16 for 15N160E
# Completed SKYSAT C17 for 15N160E
# Completed SKYSAT C18 for 15N160E
# Completed SKYSAT C19 for 15N160E
# Completed SKYSAT C2 for 15N160E
# Completed SKYSAT C3 for 15N160E
# Completed SKYSAT C4 for 15N160E
# Completed SKYSAT C5 for 15N160E
# Completed SKYSAT C6 for 15N160E
# Completed SKYSAT C7 for 15N160E
# Completed SKYSAT C8 for 15N160E
# Completed SKYSAT C9 for 15N160E
# Completed SPOT 1 for 15N160E
# Completed SPOT 2 for 15N160E
# Completed SPOT 3 for 15N160E
# Completed SPOT 4 for 15N160E
# Completed SPOT 4 DEB for 15N160E
# Completed SPOT 5 for 15N160E
# Completed SPOT 6 for 15N160E
# Completed SPOT 7 for 15N160E
# Completed GEO: 15N160E
# Completed CAPELLA-1 for 15N159E
# Completed CAPELLA-2 for 15N159E
# Completed CAPELLA-3 (WHITNEY) for 15N159E
# Completed CAPELLA-4 (WHITNEY) for 15N159E
# Completed CAPELLA-5 (WHITNEY) for 15N159E
# Completed CAPELLA-6 (WHITNEY) for 15N159E
# Completed CAPELLA-7 (WHITNEY) for 15N159E
# Completed CAPELLA-8 (WHITNEY) for 15N159E
# Completed ICEYE-X1 for 15N159E
# Completed ICEYE-X11 for 15N159E
# Completed ICEYE-X12 for 15N159E
# Completed ICEYE-X13 for 15N159E
# Completed ICEYE-X14 for 15N159E
# Completed ICEYE-X15 for 15N159E
# Completed ICEYE-X16 for 15N159E
# Completed ICEYE-X17 for 15N159E
# Completed ICEYE-X18 for 15N159E
# Completed ICEYE-X19 for 15N159E
# Completed ICEYE-X2 for 15N159E
# Completed ICEYE-X20 for 15N159E
# Completed ICEYE-X21 for 15N159E
# Completed ICEYE-X24 for 15N159E
# Completed ICEYE-X27 for 15N159E
# Completed ICEYE-X4 for 15N159E
# Completed ICEYE-X5 for 15N159E
# Completed ICEYE-X6 for 15N159E
# Completed ICEYE-X7 for 15N159E
# Completed ICEYE-X8 for 15N159E
# Completed ICEYE-X9 for 15N159E
# Completed NOVASAR 1 for 15N159E
# Completed PLEIADES 1 for 15N159E
# Completed PLEIADES 1B for 15N159E
# Completed PNEO3 for 15N159E
# Completed PNEO4 for 15N159E
# Completed SKYSAT 1 for 15N159E
# Completed SKYSAT 2 for 15N159E
# Completed SKYSAT C1 for 15N159E
# Completed SKYSAT C10 for 15N159E
# Completed SKYSAT C11 for 15N159E
# Completed SKYSAT C12 for 15N159E
# Completed SKYSAT C13 for 15N159E
# Completed SKYSAT C14 for 15N159E
# Completed SKYSAT C15 for 15N159E
# Completed SKYSAT C16 for 15N159E
# Completed SKYSAT C17 for 15N159E
# Completed SKYSAT C18 for 15N159E
# Completed SKYSAT C19 for 15N159E
# Completed SKYSAT C2 for 15N159E
# Completed SKYSAT C3 for 15N159E
# Completed SKYSAT C4 for 15N159E
# Completed SKYSAT C5 for 15N159E
# Completed SKYSAT C6 for 15N159E
# Completed SKYSAT C7 for 15N159E
# Completed SKYSAT C8 for 15N159E
# Completed SKYSAT C9 for 15N159E
# Completed SPOT 1 for 15N159E
# Completed SPOT 2 for 15N159E
# Completed SPOT 3 for 15N159E
# Completed SPOT 4 for 15N159E
# Completed SPOT 4 DEB for 15N159E
# Completed SPOT 5 for 15N159E
# Completed SPOT 6 for 15N159E
# Completed SPOT 7 for 15N159E
# Completed GEO: 15N159E
# Completed CAPELLA-1 for 15N158E
# Completed CAPELLA-2 for 15N158E
# Completed CAPELLA-3 (WHITNEY) for 15N158E
# Completed CAPELLA-4 (WHITNEY) for 15N158E
# Completed CAPELLA-5 (WHITNEY) for 15N158E
# Completed CAPELLA-6 (WHITNEY) for 15N158E
# Completed CAPELLA-7 (WHITNEY) for 15N158E
# Completed CAPELLA-8 (WHITNEY) for 15N158E
# Completed ICEYE-X1 for 15N158E
# Completed ICEYE-X11 for 15N158E
# Completed ICEYE-X12 for 15N158E
# Completed ICEYE-X13 for 15N158E
# Completed ICEYE-X14 for 15N158E
# Completed ICEYE-X15 for 15N158E
# Completed ICEYE-X16 for 15N158E
# Completed ICEYE-X17 for 15N158E
# Completed ICEYE-X18 for 15N158E
# Completed ICEYE-X19 for 15N158E
# Completed ICEYE-X2 for 15N158E
# Completed ICEYE-X20 for 15N158E
# Completed ICEYE-X21 for 15N158E
# Completed ICEYE-X24 for 15N158E
# Completed ICEYE-X27 for 15N158E
# Completed ICEYE-X4 for 15N158E
# Completed ICEYE-X5 for 15N158E
# Completed ICEYE-X6 for 15N158E
# Completed ICEYE-X7 for 15N158E
# Completed ICEYE-X8 for 15N158E
# Completed ICEYE-X9 for 15N158E
# Completed NOVASAR 1 for 15N158E
# Completed PLEIADES 1 for 15N158E
# Completed PLEIADES 1B for 15N158E
# Completed PNEO3 for 15N158E
# Completed PNEO4 for 15N158E
# Completed SKYSAT 1 for 15N158E
# Completed SKYSAT 2 for 15N158E
# Completed SKYSAT C1 for 15N158E
# Completed SKYSAT C10 for 15N158E
# Completed SKYSAT C11 for 15N158E
# Completed SKYSAT C12 for 15N158E
# Completed SKYSAT C13 for 15N158E
# Completed SKYSAT C14 for 15N158E
# Completed SKYSAT C15 for 15N158E
# Completed SKYSAT C16 for 15N158E
# Completed SKYSAT C17 for 15N158E
# Completed SKYSAT C18 for 15N158E
# Completed SKYSAT C19 for 15N158E
# Completed SKYSAT C2 for 15N158E
# Completed SKYSAT C3 for 15N158E
# Completed SKYSAT C4 for 15N158E
# Completed SKYSAT C5 for 15N158E
# Completed SKYSAT C6 for 15N158E
# Completed SKYSAT C7 for 15N158E
# Completed SKYSAT C8 for 15N158E
# Completed SKYSAT C9 for 15N158E
# Completed SPOT 1 for 15N158E
# Completed SPOT 2 for 15N158E
# Completed SPOT 3 for 15N158E
# Completed SPOT 4 for 15N158E
# Completed SPOT 4 DEB for 15N158E
# Completed SPOT 5 for 15N158E
# Completed SPOT 6 for 15N158E
# Completed SPOT 7 for 15N158E
# Completed GEO: 15N158E
# Completed CAPELLA-1 for 15N157E
# Completed CAPELLA-2 for 15N157E
# Completed CAPELLA-3 (WHITNEY) for 15N157E
# Completed CAPELLA-4 (WHITNEY) for 15N157E
# Completed CAPELLA-5 (WHITNEY) for 15N157E
# Completed CAPELLA-6 (WHITNEY) for 15N157E
# Completed CAPELLA-7 (WHITNEY) for 15N157E
# Completed CAPELLA-8 (WHITNEY) for 15N157E
# Completed ICEYE-X1 for 15N157E
# Completed ICEYE-X11 for 15N157E
# Completed ICEYE-X12 for 15N157E
# Completed ICEYE-X13 for 15N157E
# Completed ICEYE-X14 for 15N157E
# Completed ICEYE-X15 for 15N157E
# Completed ICEYE-X16 for 15N157E
# Completed ICEYE-X17 for 15N157E
# Completed ICEYE-X18 for 15N157E
# Completed ICEYE-X19 for 15N157E
# Completed ICEYE-X2 for 15N157E
# Completed ICEYE-X20 for 15N157E
# Completed ICEYE-X21 for 15N157E
# Completed ICEYE-X24 for 15N157E
# Completed ICEYE-X27 for 15N157E
# Completed ICEYE-X4 for 15N157E
# Completed ICEYE-X5 for 15N157E
# Completed ICEYE-X6 for 15N157E
# Completed ICEYE-X7 for 15N157E
# Completed ICEYE-X8 for 15N157E
# Completed ICEYE-X9 for 15N157E
# Completed NOVASAR 1 for 15N157E
# Completed PLEIADES 1 for 15N157E
# Completed PLEIADES 1B for 15N157E
# Completed PNEO3 for 15N157E
# Completed PNEO4 for 15N157E
# Completed SKYSAT 1 for 15N157E
# Completed SKYSAT 2 for 15N157E
# Completed SKYSAT C1 for 15N157E
# Completed SKYSAT C10 for 15N157E
# Completed SKYSAT C11 for 15N157E
# Completed SKYSAT C12 for 15N157E
# Completed SKYSAT C13 for 15N157E
# Completed SKYSAT C14 for 15N157E
# Completed SKYSAT C15 for 15N157E
# Completed SKYSAT C16 for 15N157E
# Completed SKYSAT C17 for 15N157E
# Completed SKYSAT C18 for 15N157E
# Completed SKYSAT C19 for 15N157E
# Completed SKYSAT C2 for 15N157E
# Completed SKYSAT C3 for 15N157E
# Completed SKYSAT C4 for 15N157E
# Completed SKYSAT C5 for 15N157E
# Completed SKYSAT C6 for 15N157E
# Completed SKYSAT C7 for 15N157E
# Completed SKYSAT C8 for 15N157E
# Completed SKYSAT C9 for 15N157E
# Completed SPOT 1 for 15N157E
# Completed SPOT 2 for 15N157E
# Completed SPOT 3 for 15N157E
# Completed SPOT 4 for 15N157E
# Completed SPOT 4 DEB for 15N157E
# Completed SPOT 5 for 15N157E
# Completed SPOT 6 for 15N157E
# Completed SPOT 7 for 15N157E
# Completed GEO: 15N157E
# Completed CAPELLA-1 for 15N156E
# Completed CAPELLA-2 for 15N156E
# Completed CAPELLA-3 (WHITNEY) for 15N156E
# Completed CAPELLA-4 (WHITNEY) for 15N156E
# Completed CAPELLA-5 (WHITNEY) for 15N156E
# Completed CAPELLA-6 (WHITNEY) for 15N156E
# Completed CAPELLA-7 (WHITNEY) for 15N156E
# Completed CAPELLA-8 (WHITNEY) for 15N156E
# Completed ICEYE-X1 for 15N156E
# Completed ICEYE-X11 for 15N156E
# Completed ICEYE-X12 for 15N156E
# Completed ICEYE-X13 for 15N156E
# Completed ICEYE-X14 for 15N156E
# Completed ICEYE-X15 for 15N156E
# Completed ICEYE-X16 for 15N156E
# Completed ICEYE-X17 for 15N156E
# Completed ICEYE-X18 for 15N156E
# Completed ICEYE-X19 for 15N156E
# Completed ICEYE-X2 for 15N156E
# Completed ICEYE-X20 for 15N156E
# Completed ICEYE-X21 for 15N156E
# Completed ICEYE-X24 for 15N156E
# Completed ICEYE-X27 for 15N156E
# Completed ICEYE-X4 for 15N156E
# Completed ICEYE-X5 for 15N156E
# Completed ICEYE-X6 for 15N156E
# Completed ICEYE-X7 for 15N156E
# Completed ICEYE-X8 for 15N156E
# Completed ICEYE-X9 for 15N156E
# Completed NOVASAR 1 for 15N156E
# Completed PLEIADES 1 for 15N156E
# Completed PLEIADES 1B for 15N156E
# Completed PNEO3 for 15N156E
# Completed PNEO4 for 15N156E
# Completed SKYSAT 1 for 15N156E
# Completed SKYSAT 2 for 15N156E
# Completed SKYSAT C1 for 15N156E
# Completed SKYSAT C10 for 15N156E
# Completed SKYSAT C11 for 15N156E
# Completed SKYSAT C12 for 15N156E
# Completed SKYSAT C13 for 15N156E
# Completed SKYSAT C14 for 15N156E
# Completed SKYSAT C15 for 15N156E
# Completed SKYSAT C16 for 15N156E
# Completed SKYSAT C17 for 15N156E
# Completed SKYSAT C18 for 15N156E
# Completed SKYSAT C19 for 15N156E
# Completed SKYSAT C2 for 15N156E
# Completed SKYSAT C3 for 15N156E
# Completed SKYSAT C4 for 15N156E
# Completed SKYSAT C5 for 15N156E
# Completed SKYSAT C6 for 15N156E
# Completed SKYSAT C7 for 15N156E
# Completed SKYSAT C8 for 15N156E
# Completed SKYSAT C9 for 15N156E
# Completed SPOT 1 for 15N156E
# Completed SPOT 2 for 15N156E
# Completed SPOT 3 for 15N156E
# Completed SPOT 4 for 15N156E
# Completed SPOT 4 DEB for 15N156E
# Completed SPOT 5 for 15N156E
# Completed SPOT 6 for 15N156E
# Completed SPOT 7 for 15N156E
# Completed GEO: 15N156E
# Completed CAPELLA-1 for 15N155E
# Completed CAPELLA-2 for 15N155E
# Completed CAPELLA-3 (WHITNEY) for 15N155E
# Completed CAPELLA-4 (WHITNEY) for 15N155E
# Completed CAPELLA-5 (WHITNEY) for 15N155E
# Completed CAPELLA-6 (WHITNEY) for 15N155E
# Completed CAPELLA-7 (WHITNEY) for 15N155E
# Completed CAPELLA-8 (WHITNEY) for 15N155E
# Completed ICEYE-X1 for 15N155E
# Completed ICEYE-X11 for 15N155E
# Completed ICEYE-X12 for 15N155E
# Completed ICEYE-X13 for 15N155E
# Completed ICEYE-X14 for 15N155E
# Completed ICEYE-X15 for 15N155E
# Completed ICEYE-X16 for 15N155E
# Completed ICEYE-X17 for 15N155E
# Completed ICEYE-X18 for 15N155E
# Completed ICEYE-X19 for 15N155E
# Completed ICEYE-X2 for 15N155E
# Completed ICEYE-X20 for 15N155E
# Completed ICEYE-X21 for 15N155E
# Completed ICEYE-X24 for 15N155E
# Completed ICEYE-X27 for 15N155E
# Completed ICEYE-X4 for 15N155E
# Completed ICEYE-X5 for 15N155E
# Completed ICEYE-X6 for 15N155E
# Completed ICEYE-X7 for 15N155E
# Completed ICEYE-X8 for 15N155E
# Completed ICEYE-X9 for 15N155E
# Completed NOVASAR 1 for 15N155E
# Completed PLEIADES 1 for 15N155E
# Completed PLEIADES 1B for 15N155E
# Completed PNEO3 for 15N155E
# Completed PNEO4 for 15N155E
# Completed SKYSAT 1 for 15N155E
# Completed SKYSAT 2 for 15N155E
# Completed SKYSAT C1 for 15N155E
# Completed SKYSAT C10 for 15N155E
# Completed SKYSAT C11 for 15N155E
# Completed SKYSAT C12 for 15N155E
# Completed SKYSAT C13 for 15N155E
# Completed SKYSAT C14 for 15N155E
# Completed SKYSAT C15 for 15N155E
# Completed SKYSAT C16 for 15N155E
# Completed SKYSAT C17 for 15N155E
# Completed SKYSAT C18 for 15N155E
# Completed SKYSAT C19 for 15N155E
# Completed SKYSAT C2 for 15N155E
# Completed SKYSAT C3 for 15N155E
# Completed SKYSAT C4 for 15N155E
# Completed SKYSAT C5 for 15N155E
# Completed SKYSAT C6 for 15N155E
# Completed SKYSAT C7 for 15N155E
# Completed SKYSAT C8 for 15N155E
# Completed SKYSAT C9 for 15N155E
# Completed SPOT 1 for 15N155E
# Completed SPOT 2 for 15N155E
# Completed SPOT 3 for 15N155E
# Completed SPOT 4 for 15N155E
# Completed SPOT 4 DEB for 15N155E
# Completed SPOT 5 for 15N155E
# Completed SPOT 6 for 15N155E
# Completed SPOT 7 for 15N155E
# Completed GEO: 15N155E
# Completed CAPELLA-1 for 15N154E
# Completed CAPELLA-2 for 15N154E
# Completed CAPELLA-3 (WHITNEY) for 15N154E
# Completed CAPELLA-4 (WHITNEY) for 15N154E
# Completed CAPELLA-5 (WHITNEY) for 15N154E
# Completed CAPELLA-6 (WHITNEY) for 15N154E
# Completed CAPELLA-7 (WHITNEY) for 15N154E
# Completed CAPELLA-8 (WHITNEY) for 15N154E
# Completed ICEYE-X1 for 15N154E
# Completed ICEYE-X11 for 15N154E
# Completed ICEYE-X12 for 15N154E
# Completed ICEYE-X13 for 15N154E
# Completed ICEYE-X14 for 15N154E
# Completed ICEYE-X15 for 15N154E
# Completed ICEYE-X16 for 15N154E
# Completed ICEYE-X17 for 15N154E
# Completed ICEYE-X18 for 15N154E
# Completed ICEYE-X19 for 15N154E
# Completed ICEYE-X2 for 15N154E
# Completed ICEYE-X20 for 15N154E
# Completed ICEYE-X21 for 15N154E
# Completed ICEYE-X24 for 15N154E
# Completed ICEYE-X27 for 15N154E
# Completed ICEYE-X4 for 15N154E
# Completed ICEYE-X5 for 15N154E
# Completed ICEYE-X6 for 15N154E
# Completed ICEYE-X7 for 15N154E
# Completed ICEYE-X8 for 15N154E
# Completed ICEYE-X9 for 15N154E
# Completed NOVASAR 1 for 15N154E
# Completed PLEIADES 1 for 15N154E
# Completed PLEIADES 1B for 15N154E
# Completed PNEO3 for 15N154E
# Completed PNEO4 for 15N154E
# Completed SKYSAT 1 for 15N154E
# Completed SKYSAT 2 for 15N154E
# Completed SKYSAT C1 for 15N154E
# Completed SKYSAT C10 for 15N154E
# Completed SKYSAT C11 for 15N154E
# Completed SKYSAT C12 for 15N154E
# Completed SKYSAT C13 for 15N154E
# Completed SKYSAT C14 for 15N154E
# Completed SKYSAT C15 for 15N154E
# Completed SKYSAT C16 for 15N154E
# Completed SKYSAT C17 for 15N154E
# Completed SKYSAT C18 for 15N154E
# Completed SKYSAT C19 for 15N154E
# Completed SKYSAT C2 for 15N154E
# Completed SKYSAT C3 for 15N154E
# Completed SKYSAT C4 for 15N154E
# Completed SKYSAT C5 for 15N154E
# Completed SKYSAT C6 for 15N154E
# Completed SKYSAT C7 for 15N154E
# Completed SKYSAT C8 for 15N154E
# Completed SKYSAT C9 for 15N154E
# Completed SPOT 1 for 15N154E
# Completed SPOT 2 for 15N154E
# Completed SPOT 3 for 15N154E
# Completed SPOT 4 for 15N154E
# Completed SPOT 4 DEB for 15N154E
# Completed SPOT 5 for 15N154E
# Completed SPOT 6 for 15N154E
# Completed SPOT 7 for 15N154E
# Completed GEO: 15N154E
# Completed CAPELLA-1 for 15N153E
# Completed CAPELLA-2 for 15N153E
# Completed CAPELLA-3 (WHITNEY) for 15N153E
# Completed CAPELLA-4 (WHITNEY) for 15N153E
# Completed CAPELLA-5 (WHITNEY) for 15N153E
# Completed CAPELLA-6 (WHITNEY) for 15N153E
# Completed CAPELLA-7 (WHITNEY) for 15N153E
# Completed CAPELLA-8 (WHITNEY) for 15N153E
# Completed ICEYE-X1 for 15N153E
# Completed ICEYE-X11 for 15N153E
# Completed ICEYE-X12 for 15N153E
# Completed ICEYE-X13 for 15N153E
# Completed ICEYE-X14 for 15N153E
# Completed ICEYE-X15 for 15N153E
# Completed ICEYE-X16 for 15N153E
# Completed ICEYE-X17 for 15N153E
# Completed ICEYE-X18 for 15N153E
# Completed ICEYE-X19 for 15N153E
# Completed ICEYE-X2 for 15N153E
# Completed ICEYE-X20 for 15N153E
# Completed ICEYE-X21 for 15N153E
# Completed ICEYE-X24 for 15N153E
# Completed ICEYE-X27 for 15N153E
# Completed ICEYE-X4 for 15N153E
# Completed ICEYE-X5 for 15N153E
# Completed ICEYE-X6 for 15N153E
# Completed ICEYE-X7 for 15N153E
# Completed ICEYE-X8 for 15N153E
# Completed ICEYE-X9 for 15N153E
# Completed NOVASAR 1 for 15N153E
# Completed PLEIADES 1 for 15N153E
# Completed PLEIADES 1B for 15N153E
# Completed PNEO3 for 15N153E
# Completed PNEO4 for 15N153E
# Completed SKYSAT 1 for 15N153E
# Completed SKYSAT 2 for 15N153E
# Completed SKYSAT C1 for 15N153E
# Completed SKYSAT C10 for 15N153E
# Completed SKYSAT C11 for 15N153E
# Completed SKYSAT C12 for 15N153E
# Completed SKYSAT C13 for 15N153E
# Completed SKYSAT C14 for 15N153E
# Completed SKYSAT C15 for 15N153E
# Completed SKYSAT C16 for 15N153E
# Completed SKYSAT C17 for 15N153E
# Completed SKYSAT C18 for 15N153E
# Completed SKYSAT C19 for 15N153E
# Completed SKYSAT C2 for 15N153E
# Completed SKYSAT C3 for 15N153E
# Completed SKYSAT C4 for 15N153E
# Completed SKYSAT C5 for 15N153E
# Completed SKYSAT C6 for 15N153E
# Completed SKYSAT C7 for 15N153E
# Completed SKYSAT C8 for 15N153E
# Completed SKYSAT C9 for 15N153E
# Completed SPOT 1 for 15N153E
# Completed SPOT 2 for 15N153E
# Completed SPOT 3 for 15N153E
# Completed SPOT 4 for 15N153E
# Completed SPOT 4 DEB for 15N153E
# Completed SPOT 5 for 15N153E
# Completed SPOT 6 for 15N153E
# Completed SPOT 7 for 15N153E
# Completed GEO: 15N153E
# Completed CAPELLA-1 for 15N152E
# Completed CAPELLA-2 for 15N152E
# Completed CAPELLA-3 (WHITNEY) for 15N152E
# Completed CAPELLA-4 (WHITNEY) for 15N152E
# Completed CAPELLA-5 (WHITNEY) for 15N152E
# Completed CAPELLA-6 (WHITNEY) for 15N152E
# Completed CAPELLA-7 (WHITNEY) for 15N152E
# Completed CAPELLA-8 (WHITNEY) for 15N152E
# Completed ICEYE-X1 for 15N152E
# Completed ICEYE-X11 for 15N152E
# Completed ICEYE-X12 for 15N152E
# Completed ICEYE-X13 for 15N152E
# Completed ICEYE-X14 for 15N152E
# Completed ICEYE-X15 for 15N152E
# Completed ICEYE-X16 for 15N152E
# Completed ICEYE-X17 for 15N152E
# Completed ICEYE-X18 for 15N152E
# Completed ICEYE-X19 for 15N152E
# Completed ICEYE-X2 for 15N152E
# Completed ICEYE-X20 for 15N152E
# Completed ICEYE-X21 for 15N152E
# Completed ICEYE-X24 for 15N152E
# Completed ICEYE-X27 for 15N152E
# Completed ICEYE-X4 for 15N152E
# Completed ICEYE-X5 for 15N152E
# Completed ICEYE-X6 for 15N152E
# Completed ICEYE-X7 for 15N152E
# Completed ICEYE-X8 for 15N152E
# Completed ICEYE-X9 for 15N152E
# Completed NOVASAR 1 for 15N152E
# Completed PLEIADES 1 for 15N152E
# Completed PLEIADES 1B for 15N152E
# Completed PNEO3 for 15N152E
# Completed PNEO4 for 15N152E
# Completed SKYSAT 1 for 15N152E
# Completed SKYSAT 2 for 15N152E
# Completed SKYSAT C1 for 15N152E
# Completed SKYSAT C10 for 15N152E
# Completed SKYSAT C11 for 15N152E
# Completed SKYSAT C12 for 15N152E
# Completed SKYSAT C13 for 15N152E
# Completed SKYSAT C14 for 15N152E
# Completed SKYSAT C15 for 15N152E
# Completed SKYSAT C16 for 15N152E
# Completed SKYSAT C17 for 15N152E
# Completed SKYSAT C18 for 15N152E
# Completed SKYSAT C19 for 15N152E
# Completed SKYSAT C2 for 15N152E
# Completed SKYSAT C3 for 15N152E
# Completed SKYSAT C4 for 15N152E
# Completed SKYSAT C5 for 15N152E
# Completed SKYSAT C6 for 15N152E
# Completed SKYSAT C7 for 15N152E
# Completed SKYSAT C8 for 15N152E
# Completed SKYSAT C9 for 15N152E
# Completed SPOT 1 for 15N152E
# Completed SPOT 2 for 15N152E
# Completed SPOT 3 for 15N152E
# Completed SPOT 4 for 15N152E
# Completed SPOT 4 DEB for 15N152E
# Completed SPOT 5 for 15N152E
# Completed SPOT 6 for 15N152E
# Completed SPOT 7 for 15N152E
# Completed GEO: 15N152E
# Completed CAPELLA-1 for 15N151E
# Completed CAPELLA-2 for 15N151E
# Completed CAPELLA-3 (WHITNEY) for 15N151E
# Completed CAPELLA-4 (WHITNEY) for 15N151E
# Completed CAPELLA-5 (WHITNEY) for 15N151E
# Completed CAPELLA-6 (WHITNEY) for 15N151E
# Completed CAPELLA-7 (WHITNEY) for 15N151E
# Completed CAPELLA-8 (WHITNEY) for 15N151E
# Completed ICEYE-X1 for 15N151E
# Completed ICEYE-X11 for 15N151E
# Completed ICEYE-X12 for 15N151E
# Completed ICEYE-X13 for 15N151E
# Completed ICEYE-X14 for 15N151E
# Completed ICEYE-X15 for 15N151E
# Completed ICEYE-X16 for 15N151E
# Completed ICEYE-X17 for 15N151E
# Completed ICEYE-X18 for 15N151E
# Completed ICEYE-X19 for 15N151E
# Completed ICEYE-X2 for 15N151E
# Completed ICEYE-X20 for 15N151E
# Completed ICEYE-X21 for 15N151E
# Completed ICEYE-X24 for 15N151E
# Completed ICEYE-X27 for 15N151E
# Completed ICEYE-X4 for 15N151E
# Completed ICEYE-X5 for 15N151E
# Completed ICEYE-X6 for 15N151E
# Completed ICEYE-X7 for 15N151E
# Completed ICEYE-X8 for 15N151E
# Completed ICEYE-X9 for 15N151E
# Completed NOVASAR 1 for 15N151E
# Completed PLEIADES 1 for 15N151E
# Completed PLEIADES 1B for 15N151E
# Completed PNEO3 for 15N151E
# Completed PNEO4 for 15N151E
# Completed SKYSAT 1 for 15N151E
# Completed SKYSAT 2 for 15N151E
# Completed SKYSAT C1 for 15N151E
# Completed SKYSAT C10 for 15N151E
# Completed SKYSAT C11 for 15N151E
# Completed SKYSAT C12 for 15N151E
# Completed SKYSAT C13 for 15N151E
# Completed SKYSAT C14 for 15N151E
# Completed SKYSAT C15 for 15N151E
# Completed SKYSAT C16 for 15N151E
# Completed SKYSAT C17 for 15N151E
# Completed SKYSAT C18 for 15N151E
# Completed SKYSAT C19 for 15N151E
# Completed SKYSAT C2 for 15N151E
# Completed SKYSAT C3 for 15N151E
# Completed SKYSAT C4 for 15N151E
# Completed SKYSAT C5 for 15N151E
# Completed SKYSAT C6 for 15N151E
# Completed SKYSAT C7 for 15N151E
# Completed SKYSAT C8 for 15N151E
# Completed SKYSAT C9 for 15N151E
# Completed SPOT 1 for 15N151E
# Completed SPOT 2 for 15N151E
# Completed SPOT 3 for 15N151E
# Completed SPOT 4 for 15N151E
# Completed SPOT 4 DEB for 15N151E
# Completed SPOT 5 for 15N151E
# Completed SPOT 6 for 15N151E
# Completed SPOT 7 for 15N151E
# Completed GEO: 15N151E
# Completed CAPELLA-1 for 16N165E
# Completed CAPELLA-2 for 16N165E
# Completed CAPELLA-3 (WHITNEY) for 16N165E
# Completed CAPELLA-4 (WHITNEY) for 16N165E
# Completed CAPELLA-5 (WHITNEY) for 16N165E
# Completed CAPELLA-6 (WHITNEY) for 16N165E
# Completed CAPELLA-7 (WHITNEY) for 16N165E
# Completed CAPELLA-8 (WHITNEY) for 16N165E
# Completed ICEYE-X1 for 16N165E
# Completed ICEYE-X11 for 16N165E
# Completed ICEYE-X12 for 16N165E
# Completed ICEYE-X13 for 16N165E
# Completed ICEYE-X14 for 16N165E
# Completed ICEYE-X15 for 16N165E
# Completed ICEYE-X16 for 16N165E
# Completed ICEYE-X17 for 16N165E
# Completed ICEYE-X18 for 16N165E
# Completed ICEYE-X19 for 16N165E
# Completed ICEYE-X2 for 16N165E
# Completed ICEYE-X20 for 16N165E
# Completed ICEYE-X21 for 16N165E
# Completed ICEYE-X24 for 16N165E
# Completed ICEYE-X27 for 16N165E
# Completed ICEYE-X4 for 16N165E
# Completed ICEYE-X5 for 16N165E
# Completed ICEYE-X6 for 16N165E
# Completed ICEYE-X7 for 16N165E
# Completed ICEYE-X8 for 16N165E
# Completed ICEYE-X9 for 16N165E
# Completed NOVASAR 1 for 16N165E
# Completed PLEIADES 1 for 16N165E
# Completed PLEIADES 1B for 16N165E
# Completed PNEO3 for 16N165E
# Completed PNEO4 for 16N165E
# Completed SKYSAT 1 for 16N165E
# Completed SKYSAT 2 for 16N165E
# Completed SKYSAT C1 for 16N165E
# Completed SKYSAT C10 for 16N165E
# Completed SKYSAT C11 for 16N165E
# Completed SKYSAT C12 for 16N165E
# Completed SKYSAT C13 for 16N165E
# Completed SKYSAT C14 for 16N165E
# Completed SKYSAT C15 for 16N165E
# Completed SKYSAT C16 for 16N165E
# Completed SKYSAT C17 for 16N165E
# Completed SKYSAT C18 for 16N165E
# Completed SKYSAT C19 for 16N165E
# Completed SKYSAT C2 for 16N165E
# Completed SKYSAT C3 for 16N165E
# Completed SKYSAT C4 for 16N165E
# Completed SKYSAT C5 for 16N165E
# Completed SKYSAT C6 for 16N165E
# Completed SKYSAT C7 for 16N165E
# Completed SKYSAT C8 for 16N165E
# Completed SKYSAT C9 for 16N165E
# Completed SPOT 1 for 16N165E
# Completed SPOT 2 for 16N165E
# Completed SPOT 3 for 16N165E
# Completed SPOT 4 for 16N165E
# Completed SPOT 4 DEB for 16N165E
# Completed SPOT 5 for 16N165E
# Completed SPOT 6 for 16N165E
# Completed SPOT 7 for 16N165E
# Completed GEO: 16N165E
# Completed CAPELLA-1 for 16N164E
# Completed CAPELLA-2 for 16N164E
# Completed CAPELLA-3 (WHITNEY) for 16N164E
# Completed CAPELLA-4 (WHITNEY) for 16N164E
# Completed CAPELLA-5 (WHITNEY) for 16N164E
# Completed CAPELLA-6 (WHITNEY) for 16N164E
# Completed CAPELLA-7 (WHITNEY) for 16N164E
# Completed CAPELLA-8 (WHITNEY) for 16N164E
# Completed ICEYE-X1 for 16N164E
# Completed ICEYE-X11 for 16N164E
# Completed ICEYE-X12 for 16N164E
# Completed ICEYE-X13 for 16N164E
# Completed ICEYE-X14 for 16N164E
# Completed ICEYE-X15 for 16N164E
# Completed ICEYE-X16 for 16N164E
# Completed ICEYE-X17 for 16N164E
# Completed ICEYE-X18 for 16N164E
# Completed ICEYE-X19 for 16N164E
# Completed ICEYE-X2 for 16N164E
# Completed ICEYE-X20 for 16N164E
# Completed ICEYE-X21 for 16N164E
# Completed ICEYE-X24 for 16N164E
# Completed ICEYE-X27 for 16N164E
# Completed ICEYE-X4 for 16N164E
# Completed ICEYE-X5 for 16N164E
# Completed ICEYE-X6 for 16N164E
# Completed ICEYE-X7 for 16N164E
# Completed ICEYE-X8 for 16N164E
# Completed ICEYE-X9 for 16N164E
# Completed NOVASAR 1 for 16N164E
# Completed PLEIADES 1 for 16N164E
# Completed PLEIADES 1B for 16N164E
# Completed PNEO3 for 16N164E
# Completed PNEO4 for 16N164E
# Completed SKYSAT 1 for 16N164E
# Completed SKYSAT 2 for 16N164E
# Completed SKYSAT C1 for 16N164E
# Completed SKYSAT C10 for 16N164E
# Completed SKYSAT C11 for 16N164E
# Completed SKYSAT C12 for 16N164E
# Completed SKYSAT C13 for 16N164E
# Completed SKYSAT C14 for 16N164E
# Completed SKYSAT C15 for 16N164E
# Completed SKYSAT C16 for 16N164E
# Completed SKYSAT C17 for 16N164E
# Completed SKYSAT C18 for 16N164E
# Completed SKYSAT C19 for 16N164E
# Completed SKYSAT C2 for 16N164E
# Completed SKYSAT C3 for 16N164E
# Completed SKYSAT C4 for 16N164E
# Completed SKYSAT C5 for 16N164E
